# %% [markdown]
# # Graph Mining First Homework
#     Questions PDF here (persian)
#
# ## First Question:
#     Consider graph below
#     ![1.png](attachment:2e6abeb1-80c9-405f-9e4d-e5b3829433f9.png)
